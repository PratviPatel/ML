# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
read = pd.read_csv("C:/Users/Lenovo/Downloads/ML-main/ML-main/World Energy Consumption.csv")

# %%
read
# Out:
#       iso_code      country  year  coal_prod_change_pct  coal_prod_change_twh  \
# 0          AFG  Afghanistan  1900                   NaN                   NaN
# 1          AFG  Afghanistan  1901                   NaN                 0.000
# 2          AFG  Afghanistan  1902                   NaN                 0.000
# 3          AFG  Afghanistan  1903                   NaN                 0.000
# 4          AFG  Afghanistan  1904                   NaN                 0.000
# ...        ...          ...   ...                   ...                   ...
# 17427      ZWE     Zimbabwe  2015               -25.013               -10.847
# 17428      ZWE     Zimbabwe  2016               -37.694               -12.257
# 17429      ZWE     Zimbabwe  2017                 8.375                 1.697
# 17430      ZWE     Zimbabwe  2018                22.555                 4.952
# 17431      ZWE     Zimbabwe  2019               -35.015                -9.422
#
# ...

# %%
read.iloc[30:41,:4] & read.loc[:,['oil_prod_change_pct']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_logical_op(x, y, op)
#     301         #  (xint or xbool) and (yint or bool)
# --> 302         result = op(x, y)
#     303     except TypeError:
#
# TypeError: unsupported operand type(s) for &: 'float' and 'bool'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15140/3758386364.py in <module>
# ----> 1 read.iloc[30:41,:4] & read.loc[:,['oil_prod_change_pct']]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# ...

# %%
read.drop(read[read['country'] == "Zimbabwe"].index,inplace=False)
read.drop(read[read['country'] == "Afghanistan"].index,inplace=False)
read
# Out:
#       iso_code      country  year  coal_prod_change_pct  coal_prod_change_twh  \
# 0          AFG  Afghanistan  1900                   NaN                   NaN
# 1          AFG  Afghanistan  1901                   NaN                 0.000
# 2          AFG  Afghanistan  1902                   NaN                 0.000
# 3          AFG  Afghanistan  1903                   NaN                 0.000
# 4          AFG  Afghanistan  1904                   NaN                 0.000
# ...        ...          ...   ...                   ...                   ...
# 17427      ZWE     Zimbabwe  2015               -25.013               -10.847
# 17428      ZWE     Zimbabwe  2016               -37.694               -12.257
# 17429      ZWE     Zimbabwe  2017                 8.375                 1.697
# 17430      ZWE     Zimbabwe  2018                22.555                 4.952
# 17431      ZWE     Zimbabwe  2019               -35.015                -9.422
#
# ...

# %%
read.reset_index(inplace = True)

# %%
newdf = read[read['country'] == "India"]

# %%
newdf = newdf.loc[(newdf.year>1901)&(newdf.year<1910)]

# %%
read.loc[(read.country=="India")&(read.year>1901)&(read.year<1910)]
# Out:
#       index iso_code country  year  coal_prod_change_pct  \
# 7209   7209      IND   India  1902                11.897
# 7210   7210      IND   India  1903                 0.172
# 7211   7211      IND   India  1904                10.482
# 7212   7212      IND   India  1905                 2.456
# 7213   7213      IND   India  1906                16.217
# 7214   7214      IND   India  1907                13.944
# 7215   7215      IND   India  1908                14.559
# 7216   7216      IND   India  1909                -7.052
#
#       coal_prod_change_twh  gas_prod_change_pct  gas_prod_change_twh  \
# 7209                 5.102                  NaN                  0.0
# 7210                 0.083                  NaN                  0.0
# 7211                 5.039                  NaN                  0.0
# 7212                 1.304                  NaN                  0.0
# 7213                 8.824                  NaN                  0.0
# ...
